# %% [markdown]
# <a href="https://colab.research.google.com/github/KunapureddySindhusri/Fmml-labs/blob/main/Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-15 14:55:35--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   217MB/s    in 0.3s
#
# 2025-03-15 14:55:37 (217 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 16247  1611.02027v1  We report on an exploratory analysis of Emoji ...    cs
# 26221  1609.03461v2  In this letter, a very simple no-reference ima...    cs
# 23423   1204.1393v1  In this paper we present a novel slanted-plane...    cs
# 20456  1602.04936v1  In this paper we proposed reinforcement learni...    cs
# 7478   1801.03329v2  We consider the task of weakly supervised one-...  stat
# ...             ...                                                ...   ...
# 538    1607.03474v5  Many sequential processing tasks require compl...    cs
# 6860   1706.09395v1  In this paper, we study the missing sample rec...  stat
# 1815   1704.02686v2  Most popular word embedding techniques involve...  stat
# 9588   1802.06816v1  The rapidly growing body of research in advers...    cs
# 10646   1206.4616v1  Driven by the multi-level structure of human i...  stat
#
#                                                    title  year  \
# 16247  :telephone::person::sailboat::whale::okhand:; ...  2016
# 26221  MUG: A Parameterless No-Reference JPEG Quality...  2016
# 23423  Continuous Markov Random Fields for Robust Ste...  2012
# 20456  Reinforcement Learning approach for Real Time ...  2016
# 7478   Weakly Supervised One-Shot Detection with Atte...  2018
# ...                                                  ...   ...
# 538                           Recurrent Highway Networks  2016
# 6860   Recovery of Missing Samples Using Sparse Appro...  2017
# 1815            Word Embeddings via Tensor Factorization  2017
# 9588   Shield: Fast, Practical Defense and Vaccinatio...  2018
# 10646  A Hierarchical Dirichlet Process Model with Mu...  2012
#
#                                                 keywords
# 16247  [exploratory, leverages, crowdsourcing, transl...
# 26221  [reference, assessment, compressed, gradients,...
# 23423  [occlusion, boundaries, formulate, inference, ...
# 20456  [reinforcement, algorithms, generalized, algor...
# 7478   [supervised, detection, detection, existence, ...
# ...                                                  ...
# 538    [sequential, processing, nonlinear, transition...
# 6860   [approximation, investigate, algorithms, assoc...
# 1815   [embedding, techniques, factorization, occurre...
# 9588   [adversarial, demonstrated, vulnerable, advers...
# 10646  [structure, intracranial, electroencephalogram...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 16247    [exploratory, leverages, crowdsourcing, transl...
# 26221    [reference, assessment, compressed, gradients,...
# 23423    [occlusion, boundaries, formulate, inference, ...
# 20456    [reinforcement, algorithms, generalized, algor...
# 7478     [supervised, detection, detection, existence, ...
#                                ...
# 38636    [deflectometric, tomography, characterization,...
# 15149    [incremental, transcripts, incrementally, info...
# 9504     [navigation, facilitate, artificial, landmarks...
# 18788    [coherence, criterion, previsions, expressed, ...
# 15182    [distributed, representations, semantics, demo...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8768 words.
# Out of those 4587 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="14b09e4d-5bb0-46cf-b800-061a68b8cde0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14b09e4d-5bb0-46cf-b800-061a68b8cde0")) {                    Plotly.newPlot(                        "14b09e4d-5bb0-46cf-b800-061a68b8cde0",                        [{"x":["alignment","differences","leverages","experiments","repetition","distributions","translate","distinctive","preserved","translation","exploratory","crowdsourcing","semantics","statistical","unchanged","literature","misalignment","performance","synthetic","gradients","comparable","experimental","magnitudes","boundaries","assessment","parameterless","compressed","reference","available","introduced","benchmark","independent","evaluator","efficient","variables","challenging","outperforms","occlusion","estimation","potentials","resolution","formulate","continuous","inference","physically","middlebury","junctions","interaction","reinforcement","generalized","opponents","artificial","according","intelligence","algorithms","generalised","evaluated","simulator","advantages","architecture","similarity","architectural","computing","precision","conditioned","developments","existence","supervised","representation","including","utterances","incorporated","mechanism","detection","attention","representations","different","considerably","correlation","algorithm","relationship","demonstrate","nonlinear","generalization","penalizing","canonical","multivariate","limitation","technique","relations","alleviate","transformations","regularization","scenarios","underlying","probability","empirical","achieving","structural","functions","assumptions","advantage","practically","interested","selection","candidate","hypothesis","estimator","penalized","situations","dimensional","observational","simulated","consistency","equivalence","interventions","nonparametric","independence","likelihood","smoothness","relationships","environment","discriminative","traditional","connections","limitations","diagnosis","requirement","definitions","hierarchically","automatic","segmentation","segmented","submission","gradually","challenge","difficult","appearance","primarily","therefore","convolutional","successful","knowledge","approaches","degradation","fundamental","correspond","additional","particular","efficiency","multidimensional","probabilistic","distribution","efficiently","represented","computational","probabilities","reasoning","discretization","dynamically","approximate","approximates","optimized","assumption","expectation","exhaustive","introduces","tractable","violations","sufficient","typically","particularly","maximization","discovering","violation","computationally","partially","investigate","structure","observation","approximation","constructing","statistics","alternative","expensive","gathering","applications","similarities","resemblance","databases","improving","significantly","contained","furthermore","containment","estimating","improvements","effective","significant","systematically"],"y":[52,53,32,642,4,107,7,13,11,112,11,14,116,162,6,121,4,874,133,39,93,394,5,38,47,1,30,62,301,138,200,135,3,408,135,283,250,26,197,11,109,78,126,196,6,2,4,84,130,74,3,127,111,87,618,10,131,12,89,242,160,11,132,80,23,18,37,187,388,254,12,16,107,354,150,194,745,20,78,818,62,577,54,114,1,26,22,23,243,90,21,35,79,85,108,180,163,63,72,236,78,97,12,27,144,56,43,31,10,45,171,6,73,60,24,5,14,34,60,15,71,117,96,175,44,60,41,23,25,9,183,204,19,9,14,162,137,82,19,136,394,68,356,431,20,67,29,107,276,152,15,155,194,158,94,265,62,149,7,23,109,14,54,64,31,17,66,30,4,66,124,92,27,24,4,95,48,133,361,69,115,42,60,101,61,10,442,44,2,50,100,279,21,147,0,76,106,228,226,28],"type":"bar"},{"x":["alignment","differences","leverages"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4587,), (4587, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8033333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>IFP</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Intuitionistic</span> <span style=''>fuzzy</span> <span style=''>soft</span> <span style=''>set</span> <span style=''>theory</span> <span style=''>and</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>present</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>definition</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>intuitionistic</span> <span style=''>fuzzy</span> <span style='background-color:rgba(0, 255, 0, 0.45454545454545453);'>parameterized</span> <span style=''>(IFP)</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>intuitionistic</span> <span style=''>fuzzy</span> <span style=''>soft</span> <span style=''>set</span> <span style=''>and</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.4130434782608695);'>operations</span> <span style=''>Then</span> <span style=''>we</span> <span style=''>define</span> <span style=''>IFP</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>aggregation</span> <span style=''>operator</span> <span style=''>to</span> <span style=''>form</span> <span style=''>IFP</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>intuitionistic</span> <span style=''>fuzzy</span> <span style=''>soft</span> <span style=''>decision</span> <span style=''>making</span> <span style=''>method</span> <span style=''>which</span> <span style=''>allows</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constructing</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>decision</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processes</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Orthogonal</span> <span style=''>Machine</span> <span style=''>Learning</span> <span style=''>for</span> <span style=''>Demand</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <span style=''>High</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensional</span> <span style=''>Causal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>in</span> <span style=''>Dynamic</span> <span style=''>Panels</span> <br/><br/><span style=''>There</span> <span style=''>has</span> <span style=''>been</span> <span style=''>growing</span> <span style=''>interest</span> <span style=''>in</span> <span style=''>how</span> <span style=''>economists</span> <span style=''>can</span> <span style=''>import</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>tools</span> <span style=''>designed</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accelerate</span> <span style=''>and</span> <span style=''>automate</span> <span style=''>the</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>process</span> <span style=''>while</span> <span style=''>still</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>retaining</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>desirable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>for</span> <span style=''>causal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>Focusing</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partially</span> <span style=''>linear</span> <span style=''>models</span> <span style=''>we</span> <span style=''>extend</span> <span style=''>the</span> <span style=''>Double</span> <span style=''>ML</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>allow</span> <span style=''>for</span> <span style=''>(1)</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatments</span> <span style=''>that</span> <span style=''>may</span> <span style=''>grow</span> <span style=''>with</span> <span style=''>the</span> <span style=''>sample</span> <span style=''>size</span> <span style=''>and</span> <span style=''>(2)</span> <span style=''>the</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>panel</span> <span style=''>data</span> <span style=''>under</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequentially</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exogenous</span> <span style=''>errors</span> <span style=''>Our</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style=''>(LD)</span> <span style=''>regime</span> <span style=''>directly</span> <span style=''>extends</span> <span style=''>the</span> <span style=''>work</span> <span style=''>in</span> <span style=''>Chernozhukov</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2016</span> <span style=''>by</span> <span style=''>showing</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coefficients</span> <span style=''>from</span> <span style=''>a</span> <span style=''>second</span> <span style=''>stage</span> <span style=''>ordinary</span> <span style=''>least</span> <span style=''>squares</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Deep</span> <span style=''>Linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Discriminant</span> <span style=''>Analysis</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>Deep</span> <span style=''>Linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Discriminant</span> <span style=''>Analysis</span> <span style=''>(DeepLDA)</span> <span style=''>which</span> <span style=''>learns</span> <span style=''>linearly</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>separable</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>representations</span> <span style=''>in</span> <span style=''>an</span> <span style=''>end</span> <span style=''>to</span> <span style=''>end</span> <span style=''>fashion</span> <span style=''>Classic</span> <span style=''>LDA</span> <span style=''>extracts</span> <span style=''>features</span> <span style=''>which</span> <span style=''>preserve</span> <span style=''>class</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>separability</span> <span style=''>and</span> <span style=''>is</span> <span style=''>used</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensionality</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reduction</span> <span style=''>for</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>problems</span> <span style=''>The</span> <span style=''>central</span> <span style=''>idea</span> <span style=''>of</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>is</span> <span style=''>to</span> <span style=''>put</span> <span style=''>LDA</span> <span style=''>on</span> <span style=''>top</span> <span style=''>of</span> <span style=''>a</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>This</span> <span style=''>can</span> <span style=''>be</span> <span style=''>seen</span> <span style=''>as</span> <span style=''>a</span> <span style=''>non</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extension</span> <span style=''>of</span> <span style=''>classic</span> <span style=''>LDA</span> <span style=''>Instead</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maximizing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5330739299610896);'>likelihood</span> <span style=''>of</span> <span style=''>target</span> <span style=''>labels</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>individual</span> <span style=''>samples</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>function</span> <span style=''>that</span> <span style=''>pushes</span> <span style=''>the</span> <span style=''>network</span> <span style=''>to</span> <span style=''>produce</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3435582822085891);'>distributions</span> <span style=''>which</span> <span style=''>(a)</span> <span style=''>have</span> <span style=''>low</span> <span style=''>variance</span> <span style=''>within</span> <span style=''>the</span> <span style=''>same</span> <span style=''>class</span> <span style=''>and</span> <span style=''>(b)</span> <span style=''>high</span> <span style=''>variance</span> <span style=''>between</span> <span style='background-color:rgba(0, 255, 0, 0.336322869955157);'>different</span> <span style=''>classes</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>is</span> <span style=''>derived</span> <span style=''>from</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Concept</span> <span style=''>Drift</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Detection</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adaptation</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Hierarchical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Hypothesis</span> <span style=''>Testing</span> <br/><br/><span style=''>In</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>streaming</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>environment</span> <span style=''>there</span> <span style=''>is</span> <span style=''>often</span> <span style=''>a</span> <span style=''>need</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>models</span> <span style=''>to</span> <span style=''>detect</span> <span style=''>and</span> <span style=''>adapt</span> <span style=''>to</span> <span style=''>concept</span> <span style=''>drifts</span> <span style=''>(ie</span> <span style=''>changes</span> <span style=''>in</span> <span style=''>the</span> <span style=''>joint</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>between</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictor</span> <span style=''>and</span> <span style=''>response</span> <span style=''>variables)</span> <span style=''>so</span> <span style=''>as</span> <span style=''>to</span> <span style=''>mitigate</span> <span style=''>deteriorating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>over</span> <span style=''>time</span> <span style=''>Various</span> <span style=''>concept</span> <span style=''>drift</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>in</span> <span style=''>the</span> <span style=''>past</span> <span style=''>decades</span> <span style=''>However</span> <span style=''>they</span> <span style=''>do</span> <span style=''>not</span> <span style=''>perform</span> <span style=''>well</span> <span style=''>across</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>concept</span> <span style=''>drift</span> <span style=''>types</span> <span style=''>(eg</span> <span style=''>gradual</span> <span style=''>or</span> <span style=''>abrupt</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recurrent</span> <span style=''>or</span> <span style=''>irregular)</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>data</span> <span style=''>stream</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>(eg</span> <span style=''>balanced</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>imbalanced</span> <span style=''>labels)</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>that</span> <span style=''>can</span> <span style=''>detect</span> <span style=''>and</span> <span style=''>also</span> <span style=''>adapt</span> <span style=''>to</span> <span style=''>the</span> <span style=''>various</span> <span style=''>concept</span> <span style=''>drift</span> <span style=''>types</span> <span style=''>even</span> <span style=''>in</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style='backgroun ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12628591699184108)
# 	architecture (0.08584604469670096)
# 	experimental (0.13976587442355445)
# 	segmentation (0.07236608726498758)
# 	representation (0.1376374600922313)
# 	information (0.2518623625399078)
# 	detection (0.12557644554806668)
# 	different (0.2642781128059596)
# 	recognition (0.12983327421071303)
# 	convolutional (0.13976587442355445)
#
# Some Statistics words are:
# 	variables (0.14184755174154468)
# 	stochastic (0.1468955073195356)
# 	theoretical (0.1574962140333165)
# 	algorithm (0.3932357395254922)
# 	statistical (0.16203937405350832)
# 	estimation (0.17768803634528016)
# 	distribution (0.19030792529025745)
# 	inference (0.19434628975265017)
# 	regression (0.17364967188288744)
# 	dimensional (0.19384149419485108)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3a5b9820-7bc9-47ed-8c47-312da2e26678" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a5b9820-7bc9-47ed-8c47-312da2e26678")) {                    Plotly.newPlot(                        "3a5b9820-7bc9-47ed-8c47-312da2e26678",                        [{"x":["alignment","differences","leverages","experiments","repetition","distributions","translate","distinctive","preserved","translation","exploratory","crowdsourcing","semantics","statistical","unchanged","literature","misalignment","performance","synthetic","gradients","comparable","experimental","magnitudes","boundaries","assessment","parameterless","compressed","reference","available","introduced","benchmark","independent","evaluator","efficient","variables","challenging","outperforms","occlusion","estimation","potentials","resolution","formulate","continuous","inference","physically","middlebury","junctions","interaction","reinforcement","generalized","opponents","artificial","according","intelligence","algorithms","generalised","evaluated","simulator","advantages","architecture","similarity","architectural","computing","precision","conditioned","developments","existence","supervised","representation","including","utterances","incorporated","mechanism","detection","attention","representations","different","considerably","correlation","algorithm","relationship","demonstrate","nonlinear","generalization","penalizing","canonical","multivariate","limitation","technique","relations","alleviate","transformations","regularization","scenarios","underlying","probability","empirical","achieving","structural","functions","assumptions","advantage","practically","interested","selection","candidate","hypothesis","estimator","penalized","situations","dimensional","observational","simulated","consistency","equivalence","interventions","nonparametric","independence","likelihood","smoothness","relationships","environment","discriminative","traditional","connections","limitations","diagnosis","requirement","definitions","hierarchically","automatic","segmentation","segmented","submission","gradually","challenge","difficult","appearance","primarily","therefore","convolutional","successful","knowledge","approaches","degradation","fundamental","correspond","additional","particular","efficiency","multidimensional","probabilistic","distribution","efficiently","represented","computational","probabilities","reasoning","discretization","dynamically","approximate","approximates","optimized","assumption","expectation","exhaustive","introduces","tractable","violations","sufficient","typically","particularly","maximization","discovering","violation","computationally","partially","investigate","structure","observation","approximation","constructing","statistics","alternative","expensive","gathering","applications","similarities","resemblance","databases","improving","significantly","contained","furthermore","containment","estimating","improvements","effective","significant","systematically","estimators","important","exponential","framework","increasing","expressiveness","involving","overfitting","nonstationary","interpretable","ubiquitous","temperature","generalisation","interactions","generalise","processes","arbitrarily","highlight","complexity","covariance","stationary","arbitrary","modelling","previously","developed","compounds","prediction","intervention","regression","molecular","containing","classification","evaluation","outperformed","respectively","constructed","application","simultaneously","objectives","construct","extraction","interpretability","predictive","universal","quantitative","fingerprints","properties","pertinent","descriptors","theoretical","multilabel","approximated","instantia ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	containment
# 	nonstationary
# 	sandwiched
# 	laplacians
# 	backtracking
# 	detectability
# 	uncontaminated
# 	distinguishability
# 	prognostics
# 	initiates
# 	equitable
# 	equitability
# 	degeneracy
# 	robustification
# 	semiparametric
# 	inexactly
# 	manifested
# 	particulars
# 	multiarmed
# 	marginalize
# Some words which never appear in Statistics papers:
# 	misalignment
# 	middlebury
# 	junctions
# 	opponents
# 	morphology
# 	anisotropic
# 	compositionality
# 	membranes
# 	microscope
# 	narrative
# 	manipulators
# 	prisoners
# 	referential
# 	axiomatized
# 	committed
# 	suppliers
# 	tardiness
# 	deblocking
# 	colorization
# 	typologically

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0509198523354794e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7683333333333333
